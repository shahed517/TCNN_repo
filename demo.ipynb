# %%
cd /home/ahmed348/TCNN_repo
# Out:
# /home/ahmed348/TCNN_repo
# /home/ahmed348/.conda/envs/cent7/2024.02-py311/venv/lib/python3.12/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !python /home/ahmed348/TCNN_repo/machine_learning.py
# Out:
# Input shape: torch.Size([8, 600, 127])
# output shape: torch.Size([8, 600, 80])

# %%
# !python /home/ahmed348/TCNN_repo/main.py --T 6 --root_keyword HGA_LFC --kernel_size 15,15,15 --just_evaluate True --sub 5 --speech_only_eval True

# %% [markdown]
# SUBJECT-05 ::Just silence -- avg MSE = 1.3393;
# Just speech -- avg MSE = 4.899;
# Speech & silence -- avg MSE = 2.2x
