# %%
# !cd /home/ahmed348/TCNN_repo
# !cd /home/ahmed348/SingleWordProductionDutch

# %%
# !python /home/ahmed348/TCNN_repo/main_Linear.py --root_keyword HGA_ONLY --sub 0 --just_evaluate True
# Out:
# pnr : 0
# patient number : 1, fold number : 0
# /home/ahmed348/.conda/envs/cent7/2024.02-py311/venv/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# Traceback (most recent call last):
#   File "/home/ahmed348/TCNN_repo/main_Linear.py", line 322, in <module>
#     generate_audio_hifiGAN(y_test_pred, result_path, audiosr, f'{pt}_fold_{k}_pred.wav', DEVICE)
#   File "/home/ahmed348/TCNN_repo/main_Linear.py", line 41, in generate_audio_hifiGAN
#     generator = Generator(h).to(device)
#                 ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ahmed348/.conda/envs/cent7/2024.02-py311/venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1369, in to
#     return self._apply(convert)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ahmed348/.conda/envs/cent7/2024.02-py311/venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 928, in _apply
#     module._apply(fn)
#   File "/home/ahmed348/.conda/envs/cent7/2024.02-py311/venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 955, in _apply
#     param_applied = fn(param)
#                     ^^^^^^^^^
#   File "/home/ahmed348/.conda/envs/cent7/2024.02-py311/venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1355, in convert
#     return t.to(
#            ^^^^^
# torch.AcceleratorError: CUDA error: out of memory
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
