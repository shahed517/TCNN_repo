# %%
# !cd /home/ahmed348/TCNN_repo
# !cd /home/ahmed348/SingleWordProductionDutch

# %%
# !python /home/ahmed348/TCNN_repo/main_Linear.py --root_keyword HGA_ONLY --sub 0 --just_evaluate True

# %%
# !python /home/ahmed348/generative_modeling_NZ0/dataset.py
# Out:
# /home/ahmed348/generative_modeling_NZ0/dataset.py:2: UserWarning: A NumPy version >=1.23.5 and <2.3.0 is required for this version of SciPy (detected version 2.4.3)
#   from scipy.stats import zscore
# 100%|█████████████████████████████████████████████| 3/3 [00:09<00:00,  3.11s/it]
# 3787
# torch.Size([400, 508])
